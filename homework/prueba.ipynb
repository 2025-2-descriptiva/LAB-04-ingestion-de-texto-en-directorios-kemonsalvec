# %%
import os
import zipfile
import pandas as pd

# %%
# Rutas
zip_path = "../files/input.zip"
extraer = "../input/"

# %%
# Crea la carpeta destino si no existe
os.makedirs(extraer, exist_ok=True) # os.makedirs(): Función que crea carpetas

# %%
# Descomprimir el archivo ZIP
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extraer)

# %%
# Detectar automáticamente la ruta base correcta
inner_path = os.path.join(extraer, "input")
base_path = inner_path if os.path.exists(inner_path) else extraer

# %%
data = []

# Recorre train y test
for dataset in os.listdir(base_path):
    dataset_path = os.path.join(base_path, dataset)
    if not os.path.isdir(dataset_path):
        continue


# Recorre positive, negative, neutral
    for sentiment in os.listdir(dataset_path):
        sentiment_path = os.path.join(dataset_path, sentiment)
        if not os.path.isdir(sentiment_path):
            continue

# Recorre todos los archivos .txt dentro de cada carpeta
        for filename in os.listdir(sentiment_path):
            file_path = os.path.join(sentiment_path, filename)
            if not os.path.isfile(file_path):
                continue

# Leer el contenido del archivo 
            with open(file_path, 'r', encoding="utf-8") as file:
                phrase = file.read().strip()

# Agregar a la lista como diccionario
            data.append({
                "dataset": dataset,
                "phrase": phrase,
                "target": sentiment
            })

# %%
data
# Out:
# [{'dataset': 'test',
#   'phrase': 'Jan. 6 -- Ford is struggling in the face of slowing truck and SUV sales and a surfeit of up-to-date , gotta-have cars',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': '( ADPnews ) - Feb 3 , 2010 - Finland-based steel maker Rautaruukki Oyj ( HEL : RTRKS ) , or Ruukki , said today it slipped to a larger-than-expected pretax loss of EUR 46 million ( USD 64.5 m ) in the fourth quarter of 2009 from',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'In Q2 of 2009 , profit before taxes amounted to EUR 13.6 mn , down from EUR 26.8 mn in Q2 of 2008',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'ADPnews - Jul 17 , 2009 - Finland-based steel maker Rautaruukki Oyj Ruukki HEL : RTRKS said today it slipped to a net loss of EUR 184 million USD 259.7 m for the first half of 2009 from a net profit of EUR',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': "Salonen added that data shows producers ' pulp inventories in North America are declining .",
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'In the third quarter of fiscal 2008 Efore swung to a net loss of EUR 400,000 versus a net profit of EUR 200,000 for the corresponding period of fiscal 2007',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Konecranes Oyj KCR1V FH fell 5.5 percent to 20.51 euros , the biggest fall since June',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Acando AB ( ACANB SS ) fell 8.9 percent to 13.35 kronor , the lowest close since Dec. 11',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': "In Q1 of 2009 , the company 's operating loss totalled EUR 0.3 mn , compared to a profit of EUR 3.6 mn in Q1 of 2008",
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Operating loss amounted to EUR 0.9 mn in the first half of 2006 compared to a profit of EUR 0.5 mn in the first half of 2005',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Pretax loss totalled EUR 162.3 mn compared to a profit of EUR 253.5 mn in 2007',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Finnish retail software developer Aldata Solution Oyj reported a net loss of 11.7 mln euro $ 17.2 mln for 2007 versus a net profit of 2.5 mln euro $ 3.7 mln for 2006',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'In October , UPM reported a third-quarter net loss of euro86 million $ 110 million compared with a net profit of euro120 million in 2007',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Operating result showed a loss of EUR 2.9 mn , while a year before , it showed a profit of EUR 0.6 mn',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Salcomp Oyj , the Finnish maker of mobile phone chargers , Monday posted a EUR1 .49 million loss in the second quarter compared with a 1.70 million profit in the same period the previous year',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'The operating loss amounted to EUR 0.8 mn , compared to a profit of EUR 3.9 mn a year earlier',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase':

#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Operating profit fell from EUR 7.9 mn in the second quarter of 2005 to EUR 5.1 mn in the second quarter of 2006',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Operating profit fell to EUR 23.26 mn from EUR 32.86 mn',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Operating profit fell to EUR 6.2 mn from EUR 8.5 mn in the third quarter of 2007',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Pretax profit decreased by 37 % to EUR 193.1 mn from EUR 305.6 mn',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Pretax profit totaled EUR 9.0 mn , down from EUR 36.3 mn in 2007',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Revenue in the quarter fell 8 percent to ( EURO ) 2.4 billion compared to a year earlier',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'SRV lowered its net sales estimate for the whole of 2008 due to uncertainties in housing sales',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'The company confirmed its estimate for lower revenue for the whole 2009 than the year-ago EUR93 .9 m as given in the interim report on 5 August 2009',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': "The Department Store Division 's sales fell by 8.6 % to EUR 140.2 mn",
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': "Alma Media 's operating profit amounted to EUR 11.9 mn , down from EUR 15.0 mn a year earlier",
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Commission income fell to EUR 4.6 mn from EUR 5.1 mn in the corresponding period in 2007',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Export declined by 6 percent to 16.4 million liters',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Group EBIT for the first half was EUR13 .6 m US$ 17.8 m , falling short of the EUR22 .5 m it posted for the same period of 2009',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'However , the company saw its net profit for the third quarter down to EUR 1.4 million from EUR 1.5 million for the corresponding period of 2009',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'In food trade , sales amounted to EUR320 .1 m , a decline of 1.1 %',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Operating profit totaled EUR 9.4 mn , down from EUR 11.7 mn in 2004',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Revenue was slightly down , at  x20ac 495 million $ 634 million , compared to  x20ac 497 million a year earlier',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'The total capital of funds managed by the bank decreased by 28 % to EUR 284mn by the end of September 2008',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'According to the company , in addition to normal seasonal fluctuation the market situation has weakened during autumn 2008',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'The net sales of the whole fiscal year 2008 will be lower than in 2007 and operating profit is estimated to be negative',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Sales at the unit slumped last year after the industry was hit by poor snowfall in the major resorts in the winter of 2006-07',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Due to the rapid decrease in net sales , personnel reductions have been carried out on a wider scale than initially expected',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Qualcomm estimated a first-quarter profit between 46 and 50 cents a share , excluding certain items , below the analyst estimate of 61 cents a share',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'Operating margin , however , slipped to 14.4 % from 15.1 % , dragged down by a poor performance in enterprise solutions',
#   'target': 'negative'},
#  {'dataset': 'test',
#   'phrase': 'SHARE REPURCHASE 11.01.2008 In the Helsinki Stock Exchange On behalf of Sampo plc Danske Bank A-S Helsinki Branc',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The contract value amounts to about EUR11m , the company added',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Aldata said that there are still a number of operational aspects to be defined between it and Microsoft and further details of the product and market initiatives resulting from this agreement will be available at a later date',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Biohit Oyj develops , manufactures and markets liquid handling products and diagnostic test systems for use in research , healthcare and industrial laboratories',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Ruukki 's delivery includes steel structures , including installation , for Krakeroy bascule bridge and steel piles for the bridge foundations",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Stockmann was established in 1862 in Finland and it became the first foreign company to enter Russia 's retail trade market in 1989",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'VNH generates annual net sales of about 5 mln eur and employs 21 people',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Following this increase Huhtamaki 's registered share capital is EUR360 .62 m and the number of shares outstanding is 106,063,320",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The offer of some 30 million shares aimed to raise more than  x20ac 500 million US$ 640 million , was expected to be completed by Oct. 9 , Outokumpu said',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Halonen 's office acknowledged receiving the letter but declined comment",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "It is necessary to strengthen the company 's operations , however",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Lemminkainen Infra Oy 's subsidiary Lemminkainen Sverige AB will perform the construction work , which is expected to start in early 2011 and to be completed in the summer of 2013",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Satama and Trainers ' House will remain as names and independent brands of the business areas",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': '

#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Our customers come from the following countries : UK , USA , Spain , France , Italy , Germany , China , Sweden , Norway , Netherlands , Austria , Belgium , Switzerland , Czech Republic , Serbia , Finland , Canada , Russia , Ukraine , Portugal , Denmark , Ireland , South Korea , Estonia and Liechtenstein',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Paychex has more than 100 offices serving approximately 554,000 payroll clients nationwide as of May 31 , 2009',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Payment of shares shall be effected on subscription',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "PCS Digital Guatemala has been using Tecnomen 's prepaid system in Telgua fixed networks as well as code division multiple access , or CDMA , and global system for mobile communication , or GSM , since 2003",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Related links : Flexiblebaseloadoperation TheWartsila32generating set Gasconversions This is the shorter of two versions of this press release',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Saunalahti is a part of the Elisa group',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Seller is the Finnish Elcoteq Group , the largest European electronics manufacturing services company',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Steek , which was set up in 2002 , is based in Bordeaux , southwestern France',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Tecnotree 's convergent charging solution includes functionality for prepaid and post-paid billing , charging and rating of voice calls , video calls and raw data traffic for both mobile and fixed networks",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "The acquisition does not have to be from the frozen foods or fish sector , as long as it has synergies with L+ï¿½nnen Tehtaat 's other businesses",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "The aim of the CEO 's Q&A sessions is to give further clarity on information , which has been made public already earlier",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The company offers payroll services , including payroll processing , payroll tax administration , and employee pay services , including direct deposit , check signing , and Readychex',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "The company 's share is listed in the Mid Cap segment of the NASDAQ OMX Helsinki",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The deliveries are scheduled for the summer and autumn of 2008',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The first stage of the contract covers 133 stores and 600 cash registers',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The front surfaces of these valve plates are directed towards each other',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The Line 4 will run fully underground and will comprise 10 stations which will be executed in two implementation stages',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The price of the 10,000 kroon par value bonds was 9663,51 kroons in the primary issue',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The report examines the medical equipment business structure and operations , history and products , and provides an analysis of its key medical equipment revenue lines',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The shares subscribed for under the stock options were registered in the Trade Register on 20 January 2011 , as of which date the new shares will establish shareholder rights',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The ship unloader is totally enclosed along the entire conveying line to the storage facilities',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Tieto in Latvia is represented by IT services companies TietoEnator Alise and TietoEnator , which has operations in the industries of Financial Services Cards , Retail and Logistics and IT Outsourcing and Managed Services',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Together with Latvia , Cramo will operate 54 rental outlets in the Baltic States',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': '` Nordic infrastructure construction is one of our strategic growth areas',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "`` It wo n't happen overnight",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "A coker crane will be supplied to Tesoro Corporation 's Golden Eagle Refinery in Martinez , California , while a similar crane will be delivered to BP 's Castell refinery in Spain",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'A merger between UPM and Finnish-Swedish Stora Enso is not likely either',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Additionally , information on business segments , competitors and future outlook are provided',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Additionally , the company will use the solutions to automate the preparation of financial statements according to IFRS standard',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'AffectoGenimap builds highly customised IT solutions for its customers in Finland and the Baltic countries',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'After the transaction , Tikkurila has no powder coatings related operations',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Ahlstrom Corporation STOCK EXCHANGE ANNOUNCEMENT 23.4.2007 Ahlstrom Corporation will publish its first quarter financial results 2007 on Friday , April 27 , 2007 approximately at 8.30 a.m. Finnish time',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Alma Media Corporation PRESS RELEASE March 25 , 2010 TYRV+ï¿½+ï¿½N SANOMAT PURCHASE CONFIRMED The business operations of Tyrv+ï¿½+ï¿½n Sanomat Oy will be transferred to Suomen Paikallissanomat Oy',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Altogether CapMan employs approximately 150 people in Helsinki , Stockholm , Copenhagen , Oslo , Moscow and Luxembourg',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Another firm Air Liquide was exempted because it left the market in 1998',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'As part of the reorganization , Kauko-Telko Ltd will be divided into Telko Ltd , Leipurin Ltd , Hamina Terminal Services Ltd and Kaukomarkkinat Ltd.',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'At the moment , there are approximately 20 Vianor sales offices in Russia',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Connectivity Services include outsourced Scan and Capture which transfers paper invoices into electronic format and Basware Business Transactions Service enables the customer to receive and send invoices in an electronic format',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Danske Bank is Denmark 's largest bank with 3.5 million customers",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Deliveries by Outotec will take place over 30 months',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Deliveries of Nokia 1112 , Nokia 2310 and Nokia 2610 are expected to start in the second quarter of 2006',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Delivery is due in the second half of 2011',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Eriikka S+ï¿½derstr+ï¿½m has previously held several positions in finance and control at Nokia Networks including acting as the Business Group Controller and having the corporate controller position at Nokia Siemens Networks',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Feed companies Suomen Rehu and Raisio do no import GMO feed',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Finnish drug distributor and wholesaler Oriola-KD Oyj said on October 11 , 2006 it named Anne Kariniemi vice president of its Logistics and Sourcing department as of January 15 , 2007',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Fortum expects its annual capital expenditure in the next four to five years to be within a range of EUR 0.8-1 .2 billion , as earlier announced',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'F-Secure Internet Security 2010 is a security service for surfing the web , online banking and shopping , e-mail , and other online activities',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Her work at NetApp included strategically repositioning the brand in the category and a major global relaunch',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Honkarakenne also decided yesterday to sell 88,500 of its B-series shares to key staff members for EUR 2.90 per share',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'In a letter to Economic Affairs Minister , the listed Estonian shipping company Tallink asks for the approval to be entitled to a 15 % cut in port fees in 2010',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "In a recent interview with the Financial Times ( FT ) , Sampo 's board chairman Bjorn Wahlroos said If P&C was certainly for sale and the price had been set at SEK 85 billion , confirming earlier statements",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'In a release on Oct. 28 , Peab said the two businesses will continue to be conducted under the brands Cliffton and Stockholm Entreprenad , both part of the Peab Group',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'In addition , MIDs are always online and enable full Internet browsing',
#   'target': 'neutral'},
#  {'dataset': 'test', 'phrase': "It 's not", 'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Janis Arbidans , CEO of YIT Celtnieciba , said the company was focusing on housing and real estate development market',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Kirsi Rantanen was previously development director for HK Ruokatalo 's poultry business",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': '( A spokesperson told WWD to expect a 50-50 mix of clothing and home decor .',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Mercator will use the software for its logistic , retail and wholesale operations in Slovenia and its other markets in southeastern Europe',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Microsoft last week also issued the first patch for the Windows 7 operating system beta it had released days earlier',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'M-real , which is part of Finnish paper maker Metsaliitto Group , is due to release its second-quarter report at around 12:00 EET on 5 August 2010',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Neste Oil will publish its third quarter 2008 results on Friday , 24 October 2008 at approximately 9 am ( EET )',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Niina Nenonen , Marimekko 's current director for clothing , bags and accessories lines , will take up this role",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'No decision on such sale of the now issued or existing treasury shares to YA Global has been made yet',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Number of offers received for this contract is two',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Odell has not contacted the State of Finland in this issue',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Originally posted to the PCMag.com security blog , Security Watch',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Pharmaceutical market in Belgium Global Research & Data Services published recently a market analysis about the pharmaceutical markets in Belgium',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Ponsse will divide its sales and maintenance service network into six geographical areas',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Proline Plus is available in both adjustable single and multichannel models and fixed volume single-channel models , in volume ranges from 0.1 micro litres to 10 ml',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Retail chain Suomen L+ï¿½hikauppa was given the index 5.8 , airline SAS 5.8 , TeliaSonera 's broadband 6.1 , German retail chain Lidl 6.1 , Tele Finland 's mobile subscriptions 6.1 , Tallink shipping line 6.3 , and power company Helsinki Energy 6.3",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'RL-Nordic is a part of Raiffeisen-Banking-Group Austria and is a subsidiary to Raiffeisen-Leasing GmbH in Austria',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 's business sectors are building construction , infrastructure construction and technical building services',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'SAMPO PLC Jarmo Salonen Head of Investor Relations and Group Communications tel. +358 10 516 0030 Distribution : NASDAQ OMX Helsinki The principal media Financial Supervisory Authority www.sampo.com This announcement is distributed by Thomson Reuters on behalf of Thomson Reuters clients',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Scanfil plc is a global contract manufacturer and systems supplier for communication and industrial electronics',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The approximately 20,000 dwt vessel has been ordered from India',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The bond has a value of EUR150m and a maturity of 4 years',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The businesses to be divested offer dairy , edible fats , ready-meal and ice-cream packaging to multinational and local customers',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "The company distributes Hiab 's products as well as other products",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The company does not disclose the sum it applied for',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The company has decided to stop the operations of Ruukki Construction Division in Latvia and Lithuania , and concentrate the production and logistics in Parnu , Estonia in 2009',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The company may at any time have in its possession one tenth of all its shares at the maximum',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The company reiterates its outlook for 2009',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The energy shot is packed in a 100-millilitre bag with a screw cap',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The financial details of the transaction were not disclosed',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The Financial Statements and Interim Reports will be released around at 9.00 a.m. ( Finnish time ) on the given dates',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "The flagship will open this fall in Manhattan 's Flatiron District in the `` Toy Building , '' at 200 Fifth Avenue",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "The government has instead proposed an exchange of the state 's stake in LMT to TeliaSonera 's stake in Lattelecom",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "The Group 's business sectors are Building Construction , Infrastructure Construction , Technical Building Services , and Building Products",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The huge bridge girders will be delivered to the site from our plant in Ylivieska , Finland',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The Insolvency Act regulates the amount of debt that borrowers are permitted to write off',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The market value of one crane is some USD6m , reported the Finnish news agency STT',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The MET is located in the Central Business District ( CBD ) of Bangkok',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The new Kroksberg railway tunnel will be built on a new section of track between Harnosand and Veda , forming part of the line that follows the coast of the Gulf of Bothnia',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The new name of the Sanoma Division will be Sanoma News',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "The Notice in its entirety with other proposals from the Nomination Committee and the Board will be published at least four weeks before 28 April on the company 's website and in Post - och Inrikes Tidningar and Dagens Industri",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The number of class A shares remains unchanged at 9,526,089 shares',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "The online ice chart shows no ice in the area of Estonia 's sea ports on the coast of the Gulf of Finland",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The plant is expected to start production in the first half of 2007',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The Point Village , designed by Scott Tallon Walker , will include a shopping center , office premises , a hotel and a cinema',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The previous offer was 3.4 % of voting rights and 12.3 % of capital',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The report profiles 158 companies including many key and niche players including major Nonwovens manufacturers such as Ahlstrom Corporation , Asahi Kasei Corporation , Buckeye Technologies , Inc. , EI',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The subject of the project is provide to the company like : Software programming and consultancy services , Computer-related services , Data services , Computer support and consultancy services , Internet services etc.',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The value of the order is USD 2.2 mn',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The value of the order is USD 2.3 mn',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The value of the orders is over EUR 25mn',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Their names have not yet been released',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Through the Nordic Exchange , OMX offers access to approximately 80 percent of the Nordic and Baltic securities market',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Tyrvaan Sanomat , published twice a week by Tyrvaan Sanomat Oy , appears in Sastamala and Kiikoinen',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Under the deal , Know IT will pay SEK90m ( USD12 .8 m-EUR8 .6 m ) in cash and stock',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Upon establishment , the plan is directed to approximately 20 persons',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Vacon recently announced plans to build its North American headquarters at 5 Business Park in Chambersburg',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "Vaisala 's Present Weather Detector measures visibility up to 20 km , as well as precipitation type and intensity",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'Water Treatment Products In Australia Today , Global Research & Data Services is going to publish a market analysis about the market for chemical water treatment products in Australia',
#   'target': 'neutral'},
#  {'dataset': 'test', 'phrase': 'What we think', 'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'When the product is manufactured in Finland , it is also packed in the country',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': '- The Group -ï¿½ s sales during the period were EUR 31.6 million EUR 36.6 million , 1-6/2007 and profit before taxes was EUR 0.2 1.3 million',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'The company continued the development of a fully human antibody in its VAP-1 antibody program',
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': "`` We have come out with a decision which is based on our preliminary economic , operational and environmental findings , '' Karvinen said",
#   'target': 'neutral'},
#  {'dataset': 'test',
#   'phrase': 'A filter is used to pre-process packets to determine if they need to be further processed by the processor of the network device',
#   'target': 'neutral'},
#  {'dataset': 'test',
# ...
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Yvonne Jones is owner of Chameleon Interiors',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "The building will house , for example , Respecta Oy 's Jyvaskyla premises , as well as other companies to be announced later , says Samuel Koivisto , Director of Technopolis operations in Jyvaskyla",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Affecto has participated in the program for the development of the Norwegian pension system since 2007',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "Financial Statements include the consolidated financial statements of the Group , the Board of Directors ' Report , the Auditors ' Report and the Corporate Governance Statement",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'For 2009 , net profit was EUR 3 million and the company paid a dividend of EUR 1.30 apiece',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'According to the company , a decision in the issue will be made in the summer of 2010 , at the earliest , and in the summer of 2011 , at the latest',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'N-Viro operates processing facilities independently as well as in partnership with municipalities',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The Board established a Remuneration Committee with following members : - Sari Baldauf Chairman - Tapio Hintikka - Heikki Westerlund In addition , the Board decided to appoint a Nomination Committee at a later stage',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "The deal will have no significant effect on the acquiring company 's equity ratio",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'no compensation for its news , opinions or distributions',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The money will be spread mainly over 2011 and 2012 , the company said',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Two other sites will be included later on',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The order was worth EUR 8mn',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "The broker started UPM-Kymmene , Stora Enso and Sappi with ` equal-weight ' recommendations and Holmen and Norske Skog with ` underweight ' ratings",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The Company serves approximately 3,000 customers in over 100 countries',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The purchase price was not disclosed',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The shares shall be repurchased through public trading , for which reason the shares are repurchased otherwise than in proportion to the holdings of the shareholders',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The combined value of the orders is almost EUR 3mn',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "The biggest sellers in the chain 's supermarkets in Finland are organic Pirkka tomatoes , carrots , eggs , and meat products",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The order comprises all production lines for a plywood mill , company said in a statement received by Lesprom Network',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Atria said its offer would give the Swedish company continued ownership and control of its slaughtering and cutting operations',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "The financial statements release will be available after publishing on the Company 's internet pages at www.cargotec.com",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "at 9:00 EET Alma Media 's Annual Report for 2009 is scheduled to be published in calendar week 9",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The writing and publication of Lemmink+ï¿½inen -ï¿½ s history is a continuation of earlier collaboration between Antti Tuuri and the company',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Also the development of online businesses will continue',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The contract value amounts to EUR 2.4 million',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The sales price was not disclosed',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'An earn-out payment of up to 4.0 mln euro ( $ 5.3 mln ) can also be paid depending on Intellibis financial performance in 2007',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'QPR ProcessGuide is available as a system solution with centralized storage and management of process content as well as a standalone desktop version ; QPR ProcessGuide Xpress',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The transaction is subject to a final agreement between the parties , approvals of their decision-making bodies and approval by the Finnish Competition Authority',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Arto Ryymin , born 1964 , will replace Juhani Kaisanlahti who has worked as acting EVP , Healthcare & Welfare since August 2007',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "The start of the negotiations , relating to Glaston 's efficiency program , was announced in October",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'According to Gallup Food and Farm Facts , beef consumption totaled 99mn kilos in Finland in 2007',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "In the first quarter of 2008 , Sacanfil 's net sales totalled EUR 50.0 mn and its operating profit EUR 4.7 mn",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 

#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Name of Applicant : Jot Automation OYName of Inventor : Mammila Tuomo , Piirainen Mika and Kellokoski MikaApplication No. : 2424-KOLNP-2008 ADate of filing of Application : 16-06-2008Publication Date : 30/01/200',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Negotiations with representatives of the personnel regarding the restructuring process have now been ended',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'In 2006 , 452 million tonnes CO2 of EUA ( EU Allowance ; emissions credit in EU ) was traded with an underlying market value approx',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Jon Risfelt is 49 years old holds a Master of Science in Chemical Engineering from the Swedish Royal Institute of Technology',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The talks involved the Food and Ingredients Divisions , as well as group service functions , the company said',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'All depends on financing',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'In addition to the Tulikivi Corporation , he is also currently a member of the Board of the following companies : Altia Corporation , J+ï¿½rvi-Suomen Portti Osuuskunta , Osuuskunta KPY , Profile Vehicles Oy and Voimatel Oy',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "Utah 's capital wanted to be the next U.S. headquarters of Amer Sports Corp. , a ski-equipment company",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Work on the assignment has already started and is due for completion in spring 2011',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Fortum needs a clear signal of commitment from the Government that the permit is available before the company will start the next round , Kuula says',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The transaction value is CAD 15 million approximately EUR 10 million',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The expanded plant is scheduled to be operational by the middle of October 2009',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "The solid fuel is heated before sludge is mixed therein . '",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Mursula said they tried to gather macro-economic perspective to see how Malaysia was doing',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Its 168 asset management experts manage assets worth over EUR 35 billion',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The estimated value of the deal is USD 9.2 million',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The phones are targeted at first time users in growth markets',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': '`` Serving customers locally is one of the cornerstones of customer focus for us',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The issuer is solely responsible for the content of this announcement',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'Currently Glaston employs approximately 1,500 persons',
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "These sections will be put into place to form the load-bearing steel structure of the bridge , '' says Sami Eronen , Senior Vice President , Infrastructure and Northern Europe , Ruukki Construction",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': "`` Printed fabrics and related design expertise have always been the core of Marimekko 's business and brand",
#   'target': 'neutral'},
#  {'dataset': 'train',
#   'phrase': 'The company then said it will focus its resources on clinical research',
#   'target': 'neutral'},
#  ...]

# %%
# Crear DataFrame con todos los datos
dataframe = pd.DataFrame(data)
# Out:
#      dataset                                             phrase    target
# 0       test  Jan. 6 -- Ford is struggling in the face of sl...  negative
# 1       test  ( ADPnews ) - Feb 3 , 2010 - Finland-based ste...  negative
# 2       test  In Q2 of 2009 , profit before taxes amounted t...  negative
# 3       test  ADPnews - Jul 17 , 2009 - Finland-based steel ...  negative
# 4       test  Salonen added that data shows producers ' pulp...  negative
# ...      ...                                                ...       ...
# 2259   train  The company said that paper demand increased i...  positive
# 2260   train  Outotec said it won new orders worth 492.9 mln...  positive
# 2261   train  `` The number of collection errors fell consid...  positive
# 2262   train  Both operating profit and turnover for the six...  positive
# 2263   train  Commission income rose by 25.7 % to EUR 16.1 m...  positive
#
# [2264 rows x 3 columns]

# %%
# Generar los dataset test y train
test_dataset = dataframe[dataframe["dataset"] == "test"].reset_index(drop=True)
train_dataset = dataframe[dataframe["dataset"] == "train"].reset_index(drop=True)

# %%
# Eliminar la columna dataset
test_dataset = dataframe.drop("dataset", axis=1)
train_dataset = dataframe.drop("dataset", axis=1)

# %%
 # Crear carpeta de salida
rutacsv = "..files/output"
os.makedirs(rutacsv, exist_ok=True)

# %%
# Guardar CSV
train_dataset.to_csv(os.path.join(rutacsv, "train_dataset.csv"), index=False, encoding="utf-8")
test_dataset.to_csv(os.path.join(rutacsv, "test_dataset.csv"), index=False, encoding="utf-8")
